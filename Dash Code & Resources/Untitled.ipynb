# %%
import pandas as  pd

# %%
df = pd.read_csv('kiva_el.csv')
df.head(2)
# Out:
#               LocationName  ISO      country      region  \
# 0  Ahuachapan, El Salvador  SLV  El Salvador  Ahuachapan
# 1  Ahuachapan, El Salvador  SLV  El Salvador  Ahuachapan
#
#                   world_region   MPI                        geo        lat  \
# 0  Latin America and Caribbean  0.03  (13.8216148, -89.9253233)  13.821615
# 1  Latin America and Caribbean  0.03  (13.8216148, -89.9253233)  13.821615
#
#          lon      id  ...                funded_time  term_in_months  \
# 0 -89.925323  670484  ...  2014-02-21 20:41:13+00:00            14.0
# 1 -89.925323  675795  ...                        NaN            14.0
#
#   lender_count                                               tags  \
# 0           29                                                NaN
# 1           53  #Animals, #Parent, #Supporting Family, user_fa...
#
#          borrower_genders repayment_interval        date  year     month  \
# 0  female, female, female             bullet  2014-02-15  2014  February
# ...

# %%
df.region.unique()
# Out:
# array(['Ahuachapan', 'La Libertad', 'San Miguel', 'San Vicente',
#        'Santa Ana', 'Sonsonate'], dtype=object)

# %%
df = df[df.country == 'USA']
df.head()
# Out:
# Empty DataFrame
# Columns: [LocationName, ISO, country, region, world_region, MPI, geo, lat, lon, id, funded_amount, loan_amount, activity, sector, use, country_code, currency, partner_id, posted_time, disbursed_time, funded_time, term_in_months, lender_count, tags, borrower_genders, repayment_interval, date, year, month, day]
# Index: []
#
# [0 rows x 30 columns]

# %%
df.sample(500).to_csv('kiva.csv')
# Out:
# (500, 30)

# %%
df = pd.read_csv('kiva5.csv')
df
# Out:
#    Unnamed: 0              LocationName  ISO      country       region  \
# 0        1750   San Miguel, El Salvador  SLV  El Salvador   San Miguel
# 1        2816  San Vicente, El Salvador  SLV  El Salvador  San Vicente
# 2        1626   San Miguel, El Salvador  SLV  El Salvador   San Miguel
# 3        2722   San Miguel, El Salvador  SLV  El Salvador   San Miguel
# 4        2228   San Miguel, El Salvador  SLV  El Salvador   San Miguel
#
#                   world_region   MPI                        geo        lat  \
# 0  Latin America and Caribbean  0.03  (13.4792922, -88.1779182)  13.479292
# 1  Latin America and Caribbean  0.02  (13.6390979, -88.7830612)  13.639098
# 2  Latin America and Caribbean  0.03  (13.4792922, -88.1779182)  13.479292
# 3  Latin America and Caribbean  0.03  (13.4792922, -88.1779182)  13.479292
# 4  Latin America and Caribbean  0.03  (13.4792922, -88.1779182)  13.479292
#
#          lon  ...                funded_time  term_in_months  lender_count  \
# ...
