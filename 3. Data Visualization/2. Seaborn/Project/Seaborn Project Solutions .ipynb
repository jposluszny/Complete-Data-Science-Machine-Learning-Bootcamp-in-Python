# %% [markdown]
# # Seaborn - Data Visualization Project Solutions

# %% [markdown]
# ### Scroll to where the Seaborn Section Starts

# %% [markdown]
# ![Namespace Labs](../../../labs.png)

# %%
import pandas as pd

# %%
# Load in kiva_loans.csv as df
df = pd.read_csv("../../kiva_loans.csv")

# %%
#check the head of df
df.head()
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
# ...

# %%
#check the summary of the data
df.describe()
# Out:
#                  id  funded_amount    loan_amount     partner_id  \
# count  6.712050e+05  671205.000000  671205.000000  657698.000000
# mean   9.932486e+05     785.995061     842.397107     178.199616
# std    1.966113e+05    1130.398941    1198.660073      94.247581
# min    6.530470e+05       0.000000      25.000000       9.000000
# 25%    8.230720e+05     250.000000     275.000000     126.000000
# 50%    9.927800e+05     450.000000     500.000000     145.000000
# 75%    1.163653e+06     900.000000    1000.000000     204.000000
# max    1.340339e+06  100000.000000  100000.000000     536.000000
#
#        term_in_months   lender_count
# count   671205.000000  671205.000000
# mean        13.739022      20.590922
# std          8.598919      28.459551
# min          1.000000       0.000000
# 25%          8.000000       7.000000
# 50%         13.000000      13.000000
# 75%         14.000000      24.000000
# max        158.000000    2986.000000

# %%
# Check the info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671205 entries, 0 to 671204
# Data columns (total 20 columns):
# id                    671205 non-null int64
# funded_amount         671205 non-null float64
# loan_amount           671205 non-null float64
# activity              671205 non-null object
# sector                671205 non-null object
# use                   666973 non-null object
# country_code          671197 non-null object
# country               671205 non-null object
# region                614405 non-null object
# currency              671205 non-null object
# partner_id            657698 non-null float64
# posted_time           671205 non-null object
# disbursed_time        668809 non-null object
# funded_time           622874 non-null object
# term_in_months        671205 non-null float64
# lender_count          671205 non-null int64
# tags                  499789 non-null object
# borrower_genders      666984 non-null object
# ...

# %%
# Drop all the null values
# and save the new datafarame in df_dropped
# check the info of the dropped dated
df_dropped = df.dropna()
df_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423081 entries, 2 to 671141
# Data columns (total 20 columns):
# id                    423081 non-null int64
# funded_amount         423081 non-null float64
# loan_amount           423081 non-null float64
# activity              423081 non-null object
# sector                423081 non-null object
# use                   423081 non-null object
# country_code          423081 non-null object
# country               423081 non-null object
# region                423081 non-null object
# currency              423081 non-null object
# partner_id            423081 non-null float64
# posted_time           423081 non-null object
# disbursed_time        423081 non-null object
# funded_time           423081 non-null object
# term_in_months        423081 non-null float64
# lender_count          423081 non-null int64
# tags                  423081 non-null object
# borrower_genders      423081 non-null object
# ...

# %%
# How many records have been lost as a result
# of dropping all the null values
671205 - 423081 # 248,124 records lost
# Out:
# 248124

# %%
# check for any null values
df.isnull().any()
# Out:
# id                    False
# funded_amount         False
# loan_amount           False
# activity              False
# sector                False
# use                    True
# country_code           True
# country               False
# region                 True
# currency              False
# partner_id             True
# posted_time           False
# disbursed_time         True
# funded_time            True
# term_in_months        False
# lender_count          False
# tags                   True
# borrower_genders       True
# repayment_interval    False
# date                  False
# dtype: bool

# %%
# Filling USE with RECORD UNKNOWN
df['use'].fillna("RECORD_UNKNOWN",inplace=True)

# %%
# Display the use column as a dataframe
df[['use']]
# Out:
#                                                       use
# 0                 To buy seasonal, fresh fruits to sell.
# 1       to repair and maintain the auto rickshaw used ...
# 2       To repair their old cycle-van and buy another ...
# 3       to purchase an embroidery machine and a variet...
# 4                                to purchase one buffalo.
# ...                                                   ...
# 671200  [True, u'para compara: cemento, arenya y ladri...
# 671201  [True, u'to start a turducken farm.'] - this l...
# 671202                                     RECORD_UNKNOWN
# 671203  [True, u'to start a turducken farm.'] - this l...
# 671204  [True, u'to start a turducken farm.'] - this l...
#
# [671205 rows x 1 columns]

# %%
# Filling region with Unknown_Region
df['region'].fillna("Unknown_Region",inplace=True)

# %%
# Display the region column as a dataframe
df[['region']]
# Out:
#                 region
# 0               Lahore
# 1               Lahore
# 2            Maynaguri
# 3               Lahore
# 4         Abdul Hakeem
# ...                ...
# 671200      Concepción
# 671201  Unknown_Region
# 671202  Unknown_Region
# 671203  Unknown_Region
# 671204  Unknown_Region
#
# [671205 rows x 1 columns]

# %%
# Create a New column that contains the year from the data column
def create_year(x):
    year = pd.DatetimeIndex(x).year 
    return year

df['year'] = create_year(df['date'])
df.head(1)
# Out:
#        id  funded_amount  loan_amount             activity sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables   Food
#
#                                        use country_code   country  region  \
# 0  To buy seasonal, fresh fruits to sell.            PK  Pakistan  Lahore
#
#   currency  ...                posted_time             disbursed_time  \
# 0      PKR  ...  2014-01-01 06:12:39+00:00  2013-12-17 08:00:00+00:00
#
#                  funded_time term_in_months  lender_count  tags  \
# 0  2014-01-02 10:06:32+00:00           12.0            12   NaN
#
#   borrower_genders repayment_interval        date  year
# 0           female          irregular  2014-01-01  2014
#
# [1 rows x 21 columns]

# %%
# Create a New column that contains the month from the data column
def create_month(x):
    month = pd.DatetimeIndex(x).month_name() 
    return month

df['month'] = create_month(df['date'])
df.head(1)
# Out:
#        id  funded_amount  loan_amount             activity sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables   Food
#
#                                        use country_code   country  region  \
# 0  To buy seasonal, fresh fruits to sell.            PK  Pakistan  Lahore
#
#   currency  ...             disbursed_time                funded_time  \
# 0      PKR  ...  2013-12-17 08:00:00+00:00  2014-01-02 10:06:32+00:00
#
#   term_in_months lender_count  tags  borrower_genders repayment_interval  \
# 0           12.0           12   NaN            female          irregular
#
#          date  year    month
# 0  2014-01-01  2014  January
#
# [1 rows x 22 columns]

# %%
# Create a New column that contains the day from the data column

def create_day(x):
    day = pd.DatetimeIndex(x).day_name() 
    return day

df['day'] = create_day(df['date'])
df.head(1)
# Out:
#        id  funded_amount  loan_amount             activity sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables   Food
#
#                                        use country_code   country  region  \
# 0  To buy seasonal, fresh fruits to sell.            PK  Pakistan  Lahore
#
#   currency  ...                funded_time term_in_months lender_count tags  \
# 0      PKR  ...  2014-01-02 10:06:32+00:00           12.0           12  NaN
#
#    borrower_genders  repayment_interval        date  year    month        day
# 0            female           irregular  2014-01-01  2014  January  Wednesday
#
# [1 rows x 23 columns]

# %%
# Create a dataframe called top_nations that contains the top nation by loan_amount
top_nations = df.groupby('country')['loan_amount'].sum().\
sort_values(ascending=False).reset_index()
top_nations.head()
# Out:
#          country  loan_amount
# 0    Philippines   55342225.0
# 1          Kenya   34534300.0
# 2  United States   31496375.0
# 3           Peru   30867400.0
# 4       Paraguay   29629075.0

# %%
# Print the unique country names
df['country'].unique()
# Out:
# array(['Pakistan', 'India', 'Kenya', 'Nicaragua', 'El Salvador',
#        'Tanzania', 'Philippines', 'Peru', 'Senegal', 'Cambodia',
#        'Liberia', 'Vietnam', 'Iraq', 'Honduras', 'Palestine', 'Mongolia',
#        'United States', 'Mali', 'Colombia', 'Tajikistan', 'Guatemala',
#        'Ecuador', 'Bolivia', 'Yemen', 'Ghana', 'Sierra Leone', 'Haiti',
#        'Chile', 'Jordan', 'Uganda', 'Burundi', 'Burkina Faso',
#        'Timor-Leste', 'Indonesia', 'Georgia', 'Ukraine', 'Kosovo',
#        'Albania', 'The Democratic Republic of the Congo', 'Costa Rica',
#        'Somalia', 'Zimbabwe', 'Cameroon', 'Turkey', 'Azerbaijan',
#        'Dominican Republic', 'Brazil', 'Mexico', 'Kyrgyzstan', 'Armenia',
#        'Paraguay', 'Lebanon', 'Samoa', 'Israel', 'Rwanda', 'Zambia',
#        'Nepal', 'Congo', 'Mozambique', 'South Africa', 'Togo', 'Benin',
#        'Belize', 'Suriname', 'Thailand', 'Nigeria', 'Mauritania',
#        'Vanuatu', 'Panama', 'Virgin Islands',
# ...

# %%
# How many unique countries are there
df['country'].nunique()
# Out:
# 87

# %%
# Create a dataframe called sectors that contains the count of the
# number of times a sector appears in the dataset
sectors = df.groupby('sector')['id'].count().\
sort_values(ascending=False).reset_index()
sectors.head()
# Out:
#          sector      id
# 0   Agriculture  180302
# 1          Food  136657
# 2        Retail  124494
# 3      Services   45140
# 4  Personal Use   36385

# %%
# Rename the id column to count
sectors.columns = ['Sector','Count']
sectors.head()
# Out:
#          Sector   Count
# 0   Agriculture  180302
# 1          Food  136657
# 2        Retail  124494
# 3      Services   45140
# 4  Personal Use   36385

# %%
# Create a dataframe called sector_loan that contains the sum of the loan
# amounts per sector
sector_loan=df.groupby('sector')['loan_amount'].sum().\
sort_values(ascending=False).reset_index()
sector_loan.head()
# Out:
#         sector  loan_amount
# 0  Agriculture  143067875.0
# 1         Food  121606150.0
# 2       Retail   98122900.0
# 3     Services   48057450.0
# 4     Clothing   37300925.0

# %%
# Check the type of sector_loan
type(sector_loan)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create a dataframe called usa that contains data from USA only
usa = df[df['country'] == 'United States']
usa.head()
# Out:
#           id  funded_amount  loan_amount               activity       sector  \
# 99   1080153         5000.0       5000.0  Food Production/Sales         Food
# 116   653415         4000.0       4000.0        Cosmetics Sales       Retail
# 231  1080154        10000.0      10000.0  Food Production/Sales         Food
# 455   653761         5000.0       5000.0                Farming  Agriculture
# 474   653803         5450.0       5450.0               Services     Services
#
#                                                    use country_code  \
# 99   hire more staff to keep up with the volume of ...           US
# 116                 to purchase more inventory to sell           US
# 231  outfit my new kitchen so that I can expand my ...           US
# 455                              to purchase a tractor           US
# 474                        to market her new business.           US
#
#            country                  region currency  ...  \
# ...

# %%
# Create a pivot table that shows the sum of loan amounts per sector
pd.pivot_table(usa, values='loan_amount',columns=['sector'],aggfunc='sum')
# Out:
# sector       Agriculture       Arts   Clothing  Construction  Education  \
# loan_amount    2999050.0  1351500.0  1957925.0      435900.0   870125.0
#
# sector       Entertainment       Food    Health   Housing  Manufacturing  \
# loan_amount       776725.0  7209975.0  396450.0  242850.0       213300.0
#
# sector       Personal Use     Retail   Services  Transportation  Wholesale
# loan_amount      481775.0  4437450.0  9420300.0        597925.0   105125.0

# %%
# Load in the themes data as themes
themes = pd.read_csv('../../loan_theme_ids.csv')
themes.head()
# Out:
#        id    Loan Theme ID          Loan Theme Type  Partner ID
# 0  638631  a1050000000skGl                  General       151.0
# 1  640322  a1050000000skGl                  General       151.0
# 2  641006  a1050000002X1ij         Higher Education       160.0
# 3  641019  a1050000002X1ij         Higher Education       160.0
# 4  641594  a1050000002VbsW  Subsistence Agriculture       336.0

# %%
# Display the columns in the themes dataset
themes.columns
# Out:
# Index(['id', 'Loan Theme ID', 'Loan Theme Type', 'Partner ID'], dtype='object')

# %%
# Display the columns in df
df.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date', 'year', 'month', 'day'],
#       dtype='object')

# %%
# Merge the themes data frame with df
# and display the merged data frame
merger = pd.merge(df,themes, on='id')
merger.head(1)
# Out:
#        id  funded_amount  loan_amount  activity          sector  \
# 0  653053          575.0        575.0  Rickshaw  Transportation
#
#                                                  use country_code   country  \
# 0  to repair and maintain the auto rickshaw used ...           PK  Pakistan
#
#    region currency  ...  tags borrower_genders repayment_interval        date  \
# 0  Lahore      PKR  ...   NaN   female, female          irregular  2014-01-01
#
#    year    month        day    Loan Theme ID Loan Theme Type Partner ID
# 0  2014  January  Wednesday  a1050000000sjEC     Underserved      247.0
#
# [1 rows x 26 columns]

# %%
# Print the unique loan theme types
merger['Loan Theme Type'].unique()
# Out:
# array(['Underserved', 'General', nan, "Hai Duong Women's Union", 'Youth',
#        'Green', 'Higher Education', 'Rural Inclusion', 'Startup',
#        'Full Tuition', 'At-Risk Youth', 'Conflict Zone',
#        'Extreme Poverty', 'Water', 'FUSAI', 'Subsistence Agriculture',
#        'Agriculture', 'Housing Improvement', 'Unbanked',
#        'Youth Entrepreneurship', 'Haiti', 'Vulnerable Populations',
#        'Primary/Secondary Education', 'Vulnerable Women', 'Murabaha',
#        'End Consumer Finance', 'Agricultural Equipment',
#        'Mobile Transactions', 'Small Enterprise', 'Business in a Box',
#        'Artisan', 'Murabaha Youth', 'Retailer Finance', 'Kiva City LA',
#        'Organic Conversion', 'First/Second Chance', 'Disaster Recovery',
#        'Agricultural Infrastructure', 'Women Without Poverty',
#        'CAMEO Partnership', 'Safe Water System for Institution',
#        'Rural Conflict Zone', 'Biodigester', 'SME',
# ...

# %%
# Which are the most prominent loan themes
merger.groupby('Loan Theme Type')['loan_amount'].sum().\
sort_values(ascending=False).reset_index().head(5)
# Out:
#           Loan Theme Type  loan_amount
# 0                 General  260493425.0
# 1             Underserved   37733925.0
# 2         Rural Inclusion   18372725.0
# 3  Vulnerable Populations   17442050.0
# 4             Agriculture   16601275.0

# %% [markdown]
# # Part Two - Visualization with Seaborn Project Solutions

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib

# %% [markdown]
# ## Categorical Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
philippines = merger[merger['country'] == 'Philippines']

# %%
philippines.head(1)
# Out:
#         id  funded_amount  loan_amount activity       sector  \
# 46  653092          175.0        175.0     Pigs  Agriculture
#
#                         use country_code      country          region  \
# 46  to buy piglets and feed           PH  Philippines  Liloy-Dela Paz
#
#    currency  ...  tags borrower_genders repayment_interval        date  year  \
# 46      PHP  ...   NaN           female          irregular  2014-01-02  2014
#
#       month       day    Loan Theme ID Loan Theme Type Partner ID
# 46  January  Thursday  a1050000000wf0Y         General      126.0
#
# [1 rows x 26 columns]

# %%
plt.figure(figsize=(12,5)) # Create a new figure
plt.title('Sector Countplot')
plt.xticks(rotation=90,fontsize=12)
sns.countplot(x='sector',data=philippines)

# %%
plt.figure(figsize=(12,6)) # Create a new figure
plt.title('Sector VS Funded Amount Violinplot')
plt.xticks(rotation=90,fontsize=12)
sns.violinplot(x='sector',y='funded_amount',data=philippines)

# %%
plt.figure(figsize=(12,6)) # Create a new figure
plt.xticks(rotation=90,fontsize=12)
sns.violinplot(x='sector',y='lender_count',data=philippines)

# %%
plt.figure(figsize=(12,6)) # Create a new figure
plt.xticks(rotation=90,fontsize=12)
sns.stripplot(x='sector',y='lender_count',data=philippines)

# %%
plt.figure(figsize=(12,6)) # Create a new figure
plt.xticks(rotation=90,fontsize=12)
sns.stripplot(x='sector',y='lender_count',data=philippines,hue='day')

# %%
plt.figure(figsize=(12,6)) # Create a new figure
plt.xticks(rotation=90,fontsize=12)
sns.stripplot(x='sector',y='lender_count',data=philippines,hue='month')

# %%
# Distribution of funded amount within sectors
plt.figure(figsize=(12,6)) # Create a new figure
plt.xticks(rotation=90,fontsize=12)
sns.boxplot(x="sector", y="funded_amount", data=philippines)

# %%
philippines.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date', 'year', 'month', 'day', 'Loan Theme ID', 'Loan Theme Type',
#        'Partner ID'],
#       dtype='object')

# %%
# Distribution of funded amount within sectors
plt.figure(figsize=(20,10)) # Create a new figure
plt.xticks(rotation=90,fontsize=12)
sns.boxplot(x="sector", y="funded_amount", data=philippines)

# %%
# Distribution of funded amount within sectors
plt.figure(figsize=(20,10)) # Create a new figure
plt.xticks(rotation=90,fontsize=12)
sns.boxenplot(x="sector", y="funded_amount", data=philippines)

# %%
region = philippines.groupby('region')['loan_amount'].sum().sort_values(ascending = False).reset_index()
region.head(2)
# Out:
#             region  loan_amount
# 0   Narra, Palawan    1235750.0
# 1  Quezon, Palawan    1211875.0

# %%
top_20 = region.head(20)
plt.figure(figsize=(12,5))
plt.xticks(rotation=30)
# plt.bar(top_20['region'],top_20['loan_amount'])
sns.barplot(x='region',y='loan_amount',data=top_20)

# %%
top_20 = top_20[top_20['region'] != 'Unknown_Region']
top_20.head()
# Out:
#                           region  loan_amount
# 0                 Narra, Palawan    1235750.0
# 1                Quezon, Palawan    1211875.0
# 2         Brookes Point, Palawan    1181175.0
# 3  Kabankalan, Negros Occidental    1045225.0
# 4   Hinigaran, Negros Occidental     967900.0

# %%
plt.figure(figsize=(12,5)) # Create a new figure
plt.xticks(rotation=90,fontsize=17) # Get or set the current tick locations 
                        # and labels of the x-axis
# plt.bar(top_20['region'],top_20['loan_amount']) # plt.bar(x,height)
sns.barplot(x='region',y='loan_amount', data=top_20)
plt.xlabel('Region')
plt.ylabel('Loan Amount')
plt.title('Loan Amount Against Region')
# Out:
# Text(0.5, 1.0, 'Loan Amount Against Region')

# %%
plt.figure(figsize=(12,7)) # Create a new figure
plt.xticks(rotation=90) # Get or set the current tick locations 
                        # and labels of the x-axis
# plt.barh(top_20['region'],top_20['loan_amount']) # plt.bar(x,height)
sns.barplot(y='region',x='loan_amount', data=top_20)

# %% [markdown]
# # Section Two - Visualizing Distributions

# %%
philippines.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date', 'year', 'month', 'day', 'Loan Theme ID', 'Loan Theme Type',
#        'Partner ID'],
#       dtype='object')

# %%
plt.figure(figsize=(22,8))
# plt.scatter(philippines['funded_amount'],philippines['lender_count'],c='r',marker='*') # plt.scatter(x,y)
sns.scatterplot(x='funded_amount',y='lender_count',data=philippines)

# %%
plt.figure(figsize=(22,8))
# plt.scatter(philippines['funded_amount'],philippines['lender_count'],c='r',marker='*') # plt.scatter(x,y)
sns.scatterplot(x='funded_amount',y='lender_count',hue='sector',data=philippines)
# hue : name of variables in ``data`` 
#     Grouping variable that will produce points with different colors.
#     Can be either categorical or numeric, although color mapping will
#     behave differently in latter case.

# %%
# plt.scatter(philippines['funded_amount'],philippines['lender_count'],c='r',marker='*') # plt.scatter(x,y)
sns.jointplot(x='funded_amount',y='lender_count',color='red',data=philippines)

# %%
plt.figure(figsize=(12,5))
# plt.hist(philippines['funded_amount'],color='r')
# plt.hist(philippines['loan_amount'],color='b')
sns.distplot(philippines['funded_amount'],color='r')
sns.distplot(philippines['loan_amount'],color='b')

# %%
plt.figure(figsize=(12,5))
sns.pairplot(philippines)

# %%
sector = philippines.groupby('sector')['funded_amount'].sum().\
sort_values(ascending= False).reset_index()
sector.head()
# Out:
#         sector  funded_amount
# 0       Retail     18848550.0
# 1         Food     14559250.0
# 2  Agriculture     11815050.0
# 3     Services      1824225.0
# 4      Housing      1808700.0

# %%
sector['sector'].unique()
# Out:
# array(['Retail', 'Food', 'Agriculture', 'Services', 'Housing',
#        'Transportation', 'Clothing', 'Education', 'Arts', 'Manufacturing',
#        'Construction', 'Personal Use', 'Health', 'Entertainment',
#        'Wholesale'], dtype=object)

# %%
sector['sector'].nunique()
# Out:
# 15

# %%
plt.figure(figsize=(12,6))
# plt.plot(philippines['lender_count'])
sns.lineplot(x='funded_amount',y='lender_count',data=philippines)
sns.lineplot(x='loan_amount',y='lender_count',data=philippines)

# %% [markdown]
# # MatPlotlib Subplots with Seaborn Section

# %% [markdown]
# Add a subplot to the current figure.

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
sns.barplot(y='region',x='loan_amount', data=top_20)
plt.subplot(1,2,2)
sns.scatterplot(x='funded_amount',y='lender_count',hue='sector',data=philippines)

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.figure(figsize=(15,15))

plt.subplot(2,2,1)
sns.distplot(philippines['funded_amount'],color='r')
sns.distplot(philippines['loan_amount'],color='b')

plt.subplot(2,2,2)
plt.xticks(rotation=90) # Get or set the current tick locations and labels of the x-axis
sns.barplot(x='region',y='loan_amount', data=top_20)
plt.xlabel('Region')
plt.ylabel('Loan Amount')
plt.title('Loan Amount Against Region')

plt.subplot(2,2,3)
sns.lineplot(x='funded_amount',y='lender_count',data=philippines)

plt.subplot(2,2,4)
sns.lineplot(x='loan_amount',y='lender_count',data=philippines)

# %% [markdown]
# # Matplotlib Figures & Axes with Seaborn

# %% [markdown]
# Creates two subplots and unpack them. Create a figure and a set of subplots

# %%
fig, ax = plt.subplots(1,2, figsize = (12,6))
sns.barplot(y='region',x='loan_amount', data=top_20, ax=ax[0])
sns.scatterplot(x='funded_amount',y='lender_count',hue='sector',data=philippines,ax=ax[1])

# %%
# plt.subplot(nrows, ncols, plot_number)
fig1, ax1 = plt.subplots(2,2, figsize = (15,15))

sns.distplot(philippines['funded_amount'],color='r',ax=ax1[0,0])
sns.distplot(philippines['loan_amount'],color='b',ax=ax1[0,0])

sns.barplot(y='region',x='loan_amount', data=top_20,ax=ax1[0,1])

sns.lineplot(x='funded_amount',y='lender_count',data=philippines,ax=ax1[1,0])

sns.lineplot(x='loan_amount',y='lender_count',data=philippines,ax=ax1[1,1])
plt.tight_layout()

# %% [markdown]
# # Matrix Visualization

# %% [markdown]
# Plot rectangular data as a color-encoded matrix

# %%
corr = philippines.corr()
corr
# Out:
#                       id  funded_amount  loan_amount  partner_id  \
# id              1.000000      -0.071565    -0.066855    0.030045
# funded_amount  -0.071565       1.000000     0.976438    0.045311
# loan_amount    -0.066855       0.976438     1.000000    0.035690
# partner_id      0.030045       0.045311     0.035690    1.000000
# term_in_months -0.084007       0.079585     0.105319   -0.052731
# lender_count   -0.249049       0.763405     0.747766    0.000424
# year            0.964651      -0.074655    -0.072371    0.032916
# Partner ID      0.030045       0.045311     0.035690    1.000000
#
#                 term_in_months  lender_count      year  Partner ID
# id                   -0.084007     -0.249049  0.964651    0.030045
# funded_amount         0.079585      0.763405 -0.074655    0.045311
# loan_amount           0.105319      0.747766 -0.072371    0.035690
# partner_id           -0.052731      0.000424  0.032916    1.000000
# ...

# %%
corr.drop(['id','partner_id','Partner ID'], axis=0,inplace=True)
corr.drop(['id','partner_id','Partner ID'], axis=1,inplace=True)
corr
# Out:
#                 funded_amount  loan_amount  term_in_months  lender_count  \
# funded_amount        1.000000     0.976438        0.079585      0.763405
# loan_amount          0.976438     1.000000        0.105319      0.747766
# term_in_months       0.079585     0.105319        1.000000      0.196910
# lender_count         0.763405     0.747766        0.196910      1.000000
# year                -0.074655    -0.072371       -0.085327     -0.245717
#
#                     year
# funded_amount  -0.074655
# loan_amount    -0.072371
# term_in_months -0.085327
# lender_count   -0.245717
# year            1.000000

# %%
plt.figure(figsize=(15,6))
sns.heatmap(corr, cmap="YlGnBu")

# %%
plt.figure(figsize=(15,6))
sns.heatmap(corr, cmap="coolwarm", annot=True)

# %% [markdown]
# # Visualize Linear Relationships

# %%
# Fits a linear regression line and plots the resulting line
plt.figure(figsize=(15,6))
plt.title('Funded Amount and Lender Count Regression Plot')
plt.xlabel('Funded Amount')
plt.ylabel('Lender Count')
sns.regplot(x="funded_amount", y="lender_count", data=philippines,    marker='^',color='r')

# %%
# Fits a regression line and plots the resulting line
sns.lmplot(x="funded_amount", y="lender_count", data=philippines)

# %%
# Fits a regression line and plots the resulting line
sns.lmplot(x="funded_amount", markers=["x"],y="lender_count",data=philippines)

# %%
# Fits a regression line and plots the resulting line
sns.lmplot(x="funded_amount", y="lender_count",hue='sector',data=philippines)

# %%
sns.lmplot(x="funded_amount", y="lender_count", col="day", data=philippines,col_wrap=3, height=4)

# %%
sns.lmplot(x="funded_amount", y="lender_count", col="month", data=philippines,col_wrap=3, height=4)

# %%
sns.jointplot(x="loan_amount", y="lender_count", data=philippines, kind="reg")

# %% [markdown]
# # Seaborn Multi-Plot Grids

# %%
sector.head()
# Out:
#         sector  funded_amount
# 0       Retail     18848550.0
# 1         Food     14559250.0
# 2  Agriculture     11815050.0
# 3     Services      1824225.0
# 4      Housing      1808700.0

# %%
g = sns.FacetGrid(philippines, col="day",height=4, aspect=.5)
g.map(plt.scatter, "funded_amount", "lender_count", alpha=.7,color='y')
g.add_legend()

# %%
g = sns.FacetGrid(philippines, col="day",height=7, aspect=0.3,hue="sector")
g.map(plt.scatter, "funded_amount", "lender_count", alpha=.7)
g.add_legend()

# %%
ordered_days = philippines.day.value_counts().index
g = sns.FacetGrid(philippines, row="day", row_order=ordered_days,
                  height=1.7, aspect=4,)
g.map(sns.lineplot, "funded_amount","lender_count",color='r')

# %%
g = sns.PairGrid(philippines)
g.map(plt.scatter)

# %%
g = sns.PairGrid(philippines,hue='sector')
g.map(plt.scatter)
g.add_legend()

# %% [markdown]
# # Word Cloud Section

# %%
from wordcloud import WordCloud, STOPWORDS
corpus = ' '.join(philippines['use'].astype(str))
corpus = corpus.replace('.', '. ')
wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white',width=2400,height=2000).generate(corpus)
plt.figure(figsize=(12,15))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
corpus = ' '.join(philippines['activity'])
corpus = corpus.replace('.', '. ')
wordcloud = WordCloud(stopwords=STOPWORDS, background_color='white',width=3400,height=2000).generate(corpus)
plt.figure(figsize=(12,15))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# Happy Coding!
