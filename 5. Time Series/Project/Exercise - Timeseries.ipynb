# %% [markdown]
# # Predict Total Sales using Facebook Prophet - Exercise

# %% [markdown]
# ![Namespace Labs](../../../../labs.png)

# %% [markdown]
# ### Installation

# %% [markdown]
# pip install fbprophet

# %% [markdown]
# ## Predict total sales

# %%
from fbprophet import Prophet

import pandas as pd

# %%
df = pd.read_csv('sales.csv')

# %%
# Print the head of the dataset
# Out:
#           ds            y
# 0  1/10/2011   36529.3764
# 1  1/11/2011  102403.8663
# 2  1/12/2011   36177.7578
# 3  1/13/2011   31005.6454
# 4  1/14/2011   71539.6626

# %%
# Print the tail of the dataframe
# Out:
#            ds           y
# 300  9/5/2011  55634.5004
# 301  9/6/2011  42359.4562
# 302  9/7/2011  51529.7315
# 303  9/8/2011  40329.0800
# 304  9/9/2011  44269.7119

# %%
# Create an instance of prophet
# Fit the data to the model
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Create a dataframe for future dates
# Print the head of the dataframe
# Out:
#             ds
# 665 2012-12-04
# 666 2012-12-05
# 667 2012-12-06
# 668 2012-12-07
# 669 2012-12-08

# %%
# Make predictions on the model

# %%
# Display one row from the predictions
# Out:
#             ds          trend     yhat_lower     yhat_upper    trend_lower  \
# 619 2012-10-19  183691.557354  145976.960032  211550.598398  160069.751808
#
#        trend_upper  Christmas Day  Christmas Day_lower  Christmas Day_upper  \
# 619  206609.164667            0.0                  0.0                  0.0
#
#      Christmas Day (Observed)  ...  holidays  holidays_lower  holidays_upper  \
# 619                       0.0  ...       0.0             0.0             0.0
#
#           weekly  weekly_lower  weekly_upper  multiplicative_terms  \
# 619 -5640.592314  -5640.592314  -5640.592314                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper           yhat
# 619                         0.0                         0.0  178050.965039
#
# [1 rows x 58 columns]

# %%
# Display the tail of the forecasts
# Out:
#             ds           yhat     yhat_lower     yhat_upper
# 665 2012-12-04  203842.873566  166129.173692  241394.782868
# 666 2012-12-05  196378.275251  160364.754799  234561.186291
# 667 2012-12-06  207706.137258  171481.204139  242676.497977
# 668 2012-12-07  193207.039057  157649.102469  229044.548972
# 669 2012-12-08  219668.017785  185942.282625  255656.877333

# %%
# Plot the forecast

# %%
# Plot the model components

# %%
# Perform cross validation
# Out:
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2011-05-23 00:00:00 and 2011-10-20 00:00:00
#           ds          yhat    yhat_lower    yhat_upper           y     cutoff
# 0 2011-05-24  53291.250755  34015.556411  71698.368004  55913.6541 2011-05-23
# 1 2011-05-25  39300.378504  21584.926129  59457.707014  36469.9428 2011-05-23
# 2 2011-05-26  48076.603078  30090.327092  66549.954236  50144.9709 2011-05-23
# 3 2011-05-27  45712.752782  27554.415191  64722.872238  42630.6069 2011-05-23
# 4 2011-05-29  19694.821822   1140.490427  40695.620992  10884.5330 2011-05-23

# %%
# Display the performance metrics
# Out:
#   horizon           mse          rmse           mae      mape     mdape  \
# 0  5 days  2.940757e+08  17148.634117  12208.925404  0.308797  0.273485
# 1  6 days  2.592895e+08  16102.468248  11565.669433  0.328909  0.273485
# 2  7 days  2.959048e+08  17201.883092  12606.691907  0.416869  0.273485
# 3  8 days  3.653123e+08  19113.144610  13488.731443  0.441266  0.292915
# 4  9 days  3.711585e+08  19265.473981  14195.906760  0.493750  0.303192
#
#    coverage
# 0  0.839080
# 1  0.867816
# 2  0.827586
# 3  0.793103
# 4  0.793103

# %%
# Plot the performance metrics

# %% [markdown]
# Happy Coding!
